# %%
#biblio8ikes gia to kommati ton praksewn kai gia tous xartes
#import numpy as np
import folium
 


def mapMarker(self, lats_c, lngs_c, citys1, location):

    #edw pros8etoume sto map ollous tous kombous kai ths apostaseis metaksei tous 
    #m = folium.Map(location=[lats_c.iloc[0], lngs_c.iloc[0]], zoom_start=5)

    for i in range(len(citys1) ):
        folium.Marker(location=location[i], popup= (citys1[i],location[i][0],location[i][1])).add_to(self.m)

    
    return self.m


def mapPath(self, citys1, location, distances):
    
    #edw pros8etoume sto map ollous tous kombous kai ths apostaseis metaksei tous 
    #m = folium.Map(location=[location[0][0], location[0][1]], zoom_start=5)

    for i in range(len(citys1) ):
        folium.Marker(location=location[i], popup= (citys1[i],location[i][0],location[i][1])).add_to(self.m)

    #sto simeio auto afou exoun proste8i h perioxes sto xarti tis enonoume me kokkino prenontas thn sira pou 
    #piran apo thn basi dedomenon
    for i in range(len(distances) -1):
        folium.PolyLine(locations=[location[distances[i]], location[distances[i+1]]], color='red').add_to(self.m)

    folium.PolyLine(locations=[location[distances[0]], location[distances[i+1]]], color='red').add_to(self.m)
    
    return self.m
